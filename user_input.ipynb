# %%
name = input("what is your name: ")
print(f"Welcome {name}")
# Out:
# Welcome Taneesh

# %%
age = int(input("What is your age: "))
print(f"Your age is {age}")
# Out:
# Your age is 19

# %% [markdown]
# Rectangle Area Calculation

# %%
length = int(input("What is the length of the rectangle: "))
breadth = int(input("What is the breadth of the rectangle: "))
area = length*breadth
print(f"The area of the rectangle is {area}")
# Out:
# The area of the rectangle is 30

# %% [markdown]
# Same using Typecast by converting into Float (decimals)

# %%
length = float(input("What is the length of the rectangle: "))
breadth = float(input("What is the breadth of the rectangle: "))
area = length*breadth
print(f"The area of the rectangle is {area}")
# Out:
# The area of the rectangle is 50.031000000000006

# %% [markdown]
# Shopping Cart Program

# %%
item = input("Which Item would u like to buy: ")
price = float(input("What is the price: "))
quantity = int(input("What is the quantity: "))
total = price*quantity
print(f"The total price of {quantity} {item} is {total}$")
# Out:
# The total price of 2 pasta is 21.98$
