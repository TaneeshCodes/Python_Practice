# %%
friends = 50.23

# friends = friends + 1
# friends += 1  #Augmented Assignment Operators 
# # friends = friends - 2 
# friends -= 2  #Augmented Assignment Operators
# friends = friends * 5
# friends *= 5  #Augmented Assignment Operators
# friends = friends / 1
# friends /= 1  #Augmented Assignment Operators
# friends **= 3
friends %= 4

print(friends)
# Out:
# 2.229999999999997

# %%
x = 3.14
y = 5
z = 6

# result = round(x) #Rounding Off
# result = abs(y) #Absolute value
# result = pow(y,z) # Power
# result = max(x,y,z) #Maximum value
result = min(x,y,z) #Minimum value
print(result)
# Out:
# 3.14

# %%
import math
x = int(input("Enter a number: "))
print(math.pi) #Pi Constant
print(math.e) #Exponential Constant
result = math.sqrt(x) #Square Root
print(result)
# Out:
# 3.141592653589793
# 2.718281828459045
# 3.0

# %%
y = 5.7
result1 = math.ceil(y) #Ceiling Value
result2 = math.floor(y) #Floor Value
print(result1)
print(result2)
# Out:
# 6
# 5

# %% [markdown]
# Calculation of Circumference of a Circle

# %%
import math

radius = float(input("Enter the radius of the circle: "))
calculation = 2 * math.pi * radius
print(calculation)
print(f"The Circumference of your circle is {calculation}")

print(f"The Circumference of your circle is  {round(calculation, 2)}")
# Out:
# 37.69911184307752
# The Circumference of your circle is 37.69911184307752
# The Circumference of your circle is  37.7

# %% [markdown]
# Calculation of Area of a Circle

# %%
import math

radius = float(input("Enter the radius: "))
area = math.pi * pow(radius, 2)
print(area)
print(f"The Area of your circle is {area}")
print(f"The Rounded of Area of your circle is {round(area, 2)}")
# Out:
# 113.09733552923255
# The Area of your circle is 113.09733552923255
# The Rounded of Area of your circle is 113.1

# %% [markdown]
# Calculation of Hypotenuse of a Right Angle Triangle

# %%
import math

a = float(input("Enter the value for a: "))
b = float(input("Enter the value for b: "))
combine = pow(a, 2) + pow(b, 2)
print(combine)
formula = math.sqrt(combine)
print(formula)
# Out:
# 50.0
# 7.0710678118654755
