# %%
age = int(input("Enter Your Age: "))
credit_score = int(input("Enter Your Credit Score"))
if age >= 18 and credit_score >= 650:
    print("You are eligible for credit card")
elif age >=18 and credit_score < 650:
    print("Your score is too low")
else:
    print("You are not eligible for credit card")

# Optimized Code

# age = int(input("Enter Your Age: "))
# credit_score = int(input("Enter Your Credit Score: "))

# if age >= 18:
#     if credit_score >= 650:
#         print("You are eligible for a credit card")
#     else:
#         print("Your credit score is too low")
# else:
#     print("You are not eligible for a credit card")
# Out:
# You are eligible for credit card

# %%
response = input("Would you like food? (Y/N: )")

if response == "Y":
    print("Have some food")
else:
    print("Please leave !!!!")
# Out:
# Please leave !!!!

# %%
name = input("Enter your name: ")

if name == "":
    print("You did not type your name")
else:
    print(f"Welcome {name}")
# Out:
# You did not type your name

# %%
for_sale = input("True/False: ")

if for_sale == "True":
    print("The following item is for sale")
else:
    print("item is out of stock")
# Out:
# item is out of stock
