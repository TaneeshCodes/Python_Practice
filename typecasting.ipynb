# %%
age = 19
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# Conversion

# %%
name = "Taneesh" #String
age = 19 #Integer
gpa = 8.03 #Float
is_student = True #Boolean

# %% [markdown]
# Float to Int & String

# %%
gpa = int(gpa)
print(type(gpa))
print(gpa)

gpa = str(gpa)
print(type(gpa))
print(gpa)
# Out:
# <class 'int'>
# 8
# <class 'str'>
# 8

# %% [markdown]
# Integer to String & Float

# %%
age = str(age)
print(type(age))
print(age)

age = float(age)
print(type(age))
print(age)
# Out:
# <class 'str'>
# 19.0
# <class 'float'>
# 19.0

# %% [markdown]
# String to Boolean

# %%
name1 = ""
name1 = bool(name1)

print(type(name1))
print(name1)

#Can be used to see if the user has entered the details or not. If the user has entered the details, then it will return True, else False.
# Out:
# <class 'bool'>
# False
